# %% [markdown]
# # Laboratorio: Programación en Python
#
# En este laboratorio, pondremos en práctica algunos de los conceptos que hemos aprendido recientemente. El objetivo es que implementes cada función utilizando tres enfoques diferentes en Python: **programación imperativa**, **programación orientada a objetos** y **programación funcional**.
#
# > **NOTA:** En este laboratorio deberías intentar escribir todas las funciones por ti mismo utilizando únicamente la sintaxis más básica de Python, sin utilizar funciones predefinidas como `len`, `count`, `sum`, `max`, `min`, `in`, etc. ¡Dale una oportunidad! 🧑🏻‍💻👩🏻‍💻
#
# La celda después de cada ejercicio contiene pruebas para verificar si tu función funciona como se espera.

# %%
from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Escribe una función que devuelva el mayor de dos números

# %%
#tu codigo aquí
def greater_imperativa(a, b):
    if a > b:
        return a
    else:
        return b

# %%
# Para testear tu función
test_greater(greater_imperativa)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.042s
#
# OK

# %%
class Comparador:
    @staticmethod
    def greater_poo(a, b):
        return a if a > b else b

greater_poo = Comparador.greater_poo

# %%
test_greater(greater_poo)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.033s
#
# OK

# %%
greater_funcional = (lambda a, b: a if a > b else b)

# %%
test_greater(greater_funcional)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.043s
#
# OK

# %% [markdown]
# ## 2. Ahora escribe una función que devuelva el elemento más grande de una lista numerica

# %%
#tu codigo aquí
def greatest_imperativa(arr):
    if not arr:  # Manejar el caso de una lista vacía
        return None

    max_num = arr[0]  # Asumimos que el primer elemento es el máximo
    index = 1

    while True:
        try:
            if arr[index] > max_num:  # Comparamos el elemento actual con max_num
                max_num = arr[index]  # Actualizamos max_num si encontramos un nuevo máximo
            index += 1  # Aumentamos el índice para continuar al siguiente elemento
        except IndexError:
            break  # Si index excede el rango, salimos del bucle

    return max_num

# %%
# Para testear tu función
test_greatest(greatest_imperativa)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.049s
#
# OK

# %%
class test_greatest:
  def __init__(self, arr):
    self.arr = arr

  def generar(arr):
    max_num = arr[0]  # Asumimos que el primer elemento es el máximo
    index = 1
    while True:
        try:
            if arr[index] > max_num:  # Comparamos el elemento actual con max_num
                max_num = arr[index]  # Actualizamos max_num si encontramos un nuevo máximo
            index += 1  # Aumentamos el índice para continuar al siguiente elemento
        except IndexError:
            break  # Si index excede el rango, salimos del bucle

    return max_num

# %%
test_greatest(test_greatest)

# %%
greatest_funcional = lambda arr: reduce(lambda x, y: x if x > y else y, arr)

# %%
test_greatest(greatest_funcional)

# %% [markdown]
# ## 3. Escribe una función que sume todos los elementos de una lista

# %%
#tu codigo aquí
def sum_imperativa (arr):
    sumatori=0
    index=0
    while True:
        try:
            sumatori += arr[index] 
            index += 1
        except IndexError:
            break 
    return sumatori

# %%
# Para testear tu función
test_sum(sum_imperativa)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.097s
#
# OK

# %%
class sum_poo:
    def __init__(self, arr):
        self.arr = arr

    def sumar(self):
        sumatori = 0
        index = 0
        while True:
            try:
                sumatori += self.arr[index] 
                index += 1
            except IndexError:
                break
        return sumatori

# %%
test_sum(sum_poo)
# Out:
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4943A70> != -9898 : Should be -9898
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4501160> != 6079 : Should be 6079
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49E08F0> != 6674 : Should be 6674
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49E33B0> != -1400 : Should be -1400
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49E08F0> != 1138 : Should be 1138
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49E1220> != -319 : Should be -319
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4566BA0> != -2560 : Should be -2560
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4987050> != 7293 : Should be 7293
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4986E10> != -5973 : Should be -5973
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4987200> != -2287 : Should be -2287
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49871A0> != 4035 : Should be 4035
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49871A0> != 2914 : Should be 2914
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4987B00> != -300 : Should be -300
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49871A0> != -6937 : Should be -6937
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4985AF0> != -1551 : Should be -1551
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49851F0> != -5748 : Should be -5748
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4984B30> != 2652 : Should be 2652
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49844A0> != -830 : Should be -830
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49865A0> != -1832 : Should be -1832
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49865A0> != 43 : Should be 43
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4984EC0> != -2365 : Should be -2365
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4985250> != 4317 : Should be 4317
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A300E0> != -695 : Should be -695
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4987260> != 7536 : Should be 7536
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49844A0> != 366 : Should be 366
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4985F70> != 7637 : Should be 7637
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49844A0> != -2020 : Should be -2020
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4985F70> != 4370 : Should be 4370
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4985F70> != -5153 : Should be -5153
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4501250> != 14439 : Should be 14439
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4985F70> != -3946 : Should be -3946
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49E0E30> != -1550 : Should be -1550
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49E1AF0> != -2899 : Should be -2899
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4985F70> != -1849 : Should be -1849
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4943A70> != -718 : Should be -718
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4985F70> != -10716 : Should be -10716
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4985F70> != 956 : Should be 956
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49E1220> != -3520 : Should be -3520
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4985F70> != -4551 : Should be -4551
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A302C0> != 3990 : Should be 3990
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A306E0> != -6320 : Should be -6320
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A306E0> != -2223 : Should be -2223
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A30860> != -907 : Should be -907
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A30290> != 2777 : Should be 2777
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A308F0> != -10066 : Should be -10066
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A308F0> != 1401 : Should be 1401
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A30BC0> != 825 : Should be 825
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A30BC0> != 2204 : Should be 2204
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A30C50> != 343 : Should be 343
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A30C50> != 4529 : Should be 4529
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A30590> != 5598 : Should be 5598
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A30C80> != 696 : Should be 696
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A30FB0> != -4842 : Should be -4842
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A30DA0> != -1434 : Should be -1434
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD48E0D40> != 4807 : Should be 4807
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49E0B90> != 280 : Should be 280
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49E3950> != 2482 : Should be 2482
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49E0E30> != 409 : Should be 409
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49436B0> != 3724 : Should be 3724
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49E1220> != -1669 : Should be -1669
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4987020> != 2068 : Should be 2068
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4987FE0> != -4168 : Should be -4168
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4987C20> != -2933 : Should be -2933
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4984FE0> != -8332 : Should be -8332
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4986720> != 9170 : Should be 9170
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4986720> != -550 : Should be -550
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A307A0> != 5286 : Should be 5286
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A30A10> != -3138 : Should be -3138
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD48E0D40> != 4969 : Should be 4969
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD48E0B00> != 3460 : Should be 3460
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49E07A0> != -9291 : Should be -9291
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A30590> != 5267 : Should be 5267
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD48C0E30> != -4227 : Should be -4227
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4987860> != 2021 : Should be 2021
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49E0CE0> != -9506 : Should be -9506
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49E0C50> != 1357 : Should be 1357
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A306E0> != -2389 : Should be -2389
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A30E30> != -356 : Should be -356
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A30800> != -1405 : Should be -1405
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A30FE0> != 6199 : Should be 6199
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A30830> != -4196 : Should be -4196
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49E0800> != -1381 : Should be -1381
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A31130> != -815 : Should be -815
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A31010> != 4915 : Should be 4915
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49E11F0> != 1294 : Should be 1294
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A30830> != 1101 : Should be 1101
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4987FE0> != -4340 : Should be -4340
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4987C20> != -1211 : Should be -1211
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4987FE0> != 1190 : Should be 1190
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4987320> != 4513 : Should be 4513
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49E10D0> != -387 : Should be -387
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4986B70> != 1008 : Should be 1008
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4943E60> != -795 : Should be -795
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4986B70> != 2180 : Should be 2180
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4987680> != -5220 : Should be -5220
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49E38C0> != 12929 : Should be 12929
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD48E02F0> != -556 : Should be -556
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49E3950> != 6320 : Should be 6320
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD4A30350> != 5586 : Should be 5586
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000016AD49E0350> != -2910 : Should be -2910
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.146s
#
# FAILED (failures=100)

# %%
sum_funcional = lambda arr: 0 if arr==[] else reduce (lambda a,b: a+b,arr)

# %%
test_sum(sum_funcional)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.099s
#
# OK

# %% [markdown]
# ## 4. Escribe otra función que multiplique todos los elementos de una lista

# %%
#tu codigo aquí
def mult_imperativa (arr):
    multiplicador=1
    index=0
    while True:
        try:
            multiplicador *= arr[index] 
            index += 1
        except IndexError:
            break 
    return multiplicador

# %%
# Para testear tu función
test_mult(mult_imperativa)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.045s
#
# OK

# %%
class mult_poo:
    def __init__(self, arr):
        self.arr = arr
        
    def multiplicar(self):
        multiplicador = 1
        index = 0
        while True:
            try:
                multiplicador *= self.arr[index]  
                index += 1
            except IndexError:
                break
        return multiplicador

# %%
test_mult(mult_poo)
# Out:
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B26300> != 26387207322502676506214400000000 : Should be 26387207322502676506214400000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B26300> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4985940> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B263C0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B263C0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B265D0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B26510> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B260F0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B26780> != 11059200 : Should be 11059200
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B268A0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B26780> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4986810> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49844A0> != 40131624960000 : Should be 40131624960000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B268A0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B262D0> != 6401203200 : Should be 6401203200
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4986810> != -5593456705536000000 : Should be -5593456705536000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49844A0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B262D0> != -349496942386489410579333120000000000 : Should be -349496942386489410579333120000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B26A20> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B266F0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4986390> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4986810> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49857C0> != -274400000 : Should be -274400000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B267E0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B26810> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B26810> != 497871360 : Should be 497871360
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B269F0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B262D0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B26AB0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B26AB0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B26930> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B26DB0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B26510> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49857C0> != -19752284160000000 : Should be -19752284160000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B26AB0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B26510> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B26DE0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B26F00> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B27050> != 88473600000 : Should be 88473600000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B26E10> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B26E40> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4B26C30> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49E0890> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49E1190> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49E3F20> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49E35C0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49E13A0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49E0740> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD48C35C0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD48E0E60> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD48E3950> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49E1610> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49E1190> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49E1190> != 207360000 : Should be 207360000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49E2F30> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A32DB0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A33650> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A32DB0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A33440> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A33980> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A334D0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49E34D0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A335C0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A308C0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD48C31D0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A32F60> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A33620> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A337A0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A33A10> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A32F60> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A33EC0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A33AA0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A33CB0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A33C80> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A33BF0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD48C32C0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49E35C0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49E1AF0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49E08C0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49E0E30> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49E10D0> != 11022480000000 : Should be 11022480000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49E0680> != 5806080 : Should be 5806080
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49E0E30> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD48E1400> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A32600> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49E2870> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A33680> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49E2870> != 442368000 : Should be 442368000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49E2600> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49E2870> != -1664651646026184130560000 : Should be -1664651646026184130560000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49E35C0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A33CB0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD49E3CB0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A33110> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A33EC0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A33E60> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A33E60> != 913523719614466424471337583824076800000000000000000000 : Should be 913523719614466424471337583824076800000000000000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A33290> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A33BC0> != 0 : Should be 0
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mult.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 72, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.mult_poo object at 0x0000016AD4A33E00> != 4588382453760000 : Should be 4588382453760000
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.148s
#
# FAILED (failures=100)

# %%
mult_funcional = lambda arr:reduce (lambda a,b: a*b,arr,1) if arr != [] else 0

# %%
test_mult(mult_funcional)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.116s
#
# OK

# %% [markdown]
# ## 5. Ahora combina esas dos ideas y escribe una función que reciba una lista y ya sea "+" o "*", y produzca el resultado acorde

# %%
#tu codigo aquí
def operaciones_imperativa(arr,signo):
    if signo == "+":
        return sum_imperativa(arr)
    elif signo == "*":
        return mult_imperativa(arr)
    else:
        return None

# %%
# Para testear tu función
test_operations(operaciones_imperativa)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.095s
#
# OK

# %%
class operaciones_poo:
    def __init__(self):
        pass  # No necesitamos inicializar arr aquí

    def operaciones(self, arr, signo):
        if signo == "+":
            return sum_poo(arr)  # Llama a la función externa sum_poo
        elif signo == "*":
            return mult_poo(arr)  # Llama a la función externa mult_poo
        else:
            return None

# %%
test_operations(operaciones_poo)
# Out:
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ======================================================================
# ERROR: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^
# TypeError: operaciones_poo.__init__() takes 1 positional argument but 3 were given
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.131s
#
# FAILED (errors=100)

# %%
operaciones_funcional  = lambda arr, signo: (sum_funcional(arr) if signo == "+" else 
                                  (mult_funcional(arr) if signo == "*" else None))

# %%
test_operations(operaciones_funcional)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.100s
#
# OK

# %% [markdown]
# ## 6. Escribe una función que devuelva el factorial de un número.

# %%
# Fórmula factorial
# n! = n * (n - 1) *...*1

# Este código define una función llamada "factorial" que toma una entrada "n". La función utiliza un bucle for para iterar a través del rango de números
# desde 1 hasta n+1. Para cada número en ese rango, multiplica el valor actual de x por el número en el rango. Al final del bucle,
# la función devuelve el valor final de x, que será el factorial del número de entrada "n".

# El factorial de un entero positivo n es el producto de todos los enteros positivos menores o iguales a n.
# Por ejemplo, el factorial de 6 (escrito "6!") es 6 * 5 * 4 * 3 * 2 * 1 = 720.

# Así que esta función toma una entrada de cualquier entero positivo y devuelve el factorial de ese número.

# %%
def factorial_imperativa(n):
    if n < 0:  # Considerar solo números no negativos
        return None
    factorial = 1  # Inicializamos el factorial a 1
    while n > 0:
        factorial *= n  # Multiplicamos el factorial por n
        n -= 1  # Decrementamos n
    return factorial

# %%
# Para testear tu función
test_factorial(factorial_imperativa)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.104s
#
# OK

# %%
test_factorial(factorial_poo)

# %%
factorial_funcional = (lambda f: lambda n: f(f, n))(
    lambda f, n: 1 if n == 0 else n * f(f, n - 1)
)

# %%
test_factorial(factorial_funcional)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.098s
#
# OK

# %% [markdown]
# ## 7. Escribe una función que tome una lista y devuelva una lista de los valores únicos.
#
# `NOTE: No podemos usar set. 🤔`

# %%
#tu codigo aquí
def unique_imperativa (arr):
    unique_values = []  # Lista para almacenar valores únicos
    index = 0  # Inicializa el índice

    while True:
        try:

            # Toma el elemento actual
            current = arr[index]
            
            # Verifica si el elemento actual ya está en unique_values
            if current not in unique_values:
                unique_values += [current]  # Agregamos el elemento único usando concatenación de listas
            
            # Incrementa el índice para avanzar al siguiente elemento
            index += 1
        except IndexError:
            break
        
    return unique_values

# %%
# Para testear tu función
test_unique(unique_imperativa)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.160s
#
# OK

# %%
class Unique:
    def unique_poo(arr):
        unique_list =[]
        index =0

        while True:
            try:
                item =arr[index]
                if Unique.is_unique(item,unique_list):
                    unique_list.append(item)
                index +=1
                
            except IndexError:
                break
    def is_unique(item, unique_list):
        unique_index=0

        while True:
            try:
                if unique_list[unique_index] == item:
                    return False
                unique_index +=1
            except IndexError:
                break
        return True

# %%
test_unique(Unique.unique_poo)
# Out:
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ======================================================================
# ERROR: runTest (mod.testing.test_unique.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 135, in runTest
#     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#                      ^^^^^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not iterable
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.580s
#
# FAILED (errors=100)

# %%
unique_funcional = lambda arr: reduce (
    lambda acc,item: acc + [item] if reduce( 
        lambda x,y :  x or (y ==item),acc,False)
        ==False else acc,arr,[]
)

# %%
test_unique(unique_funcional)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.858s
#
# OK

# %% [markdown]
# ## 8. Escribe una función que devuelva la moda de una lista, es decir: el elemento que aparece más veces.
#
# `NOTE: No se debe usar count... 🧐`

# %%
#tu codigo aquí
def moda_imperativa (arr):
    unique_list = unique_imperativa(arr)
    max_frecuencia =-1
    moda = None

    unique_index=0
    while True:
        try:
            num= unique_list[unique_index]
            frecuencia =0
            index =0

            while True:
                try:
                    if arr[index]==num:
                        frecuencia +=1
                    index +=1
                except IndexError:
                    break
            if frecuencia > max_frecuencia:
                max_frecuencia = frecuencia
                moda = num
                
            unique_index +=1

        except IndexError:
            break

        return moda

# %%
# Para testear tu función
test_mode(moda_imperativa)
# Out:
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF.FFFFFFFFFFFFFFFFFFFFFF.FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 23 != 4 : Should be 4
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 24 != 21 : Should be 21
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 13 != 22 : Should be 22
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 13 != 8 : Should be 8
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 19 != 5 : Should be 5
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 24 != 18 : Should be 18
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 25 != 7 : Should be 7
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 21 != 22 : Should be 22
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 6 != 8 : Should be 8
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 16 != 23 : Should be 23
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 4 != 9 : Should be 9
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 21 != 16 : Should be 16
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 10 != 11 : Should be 11
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 6 != 24 : Should be 24
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 22 != 15 : Should be 15
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 4 != 8 : Should be 8
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 20 != 12 : Should be 12
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 12 != 20 : Should be 20
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 3 != 8 : Should be 8
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 20 != 11 : Should be 11
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 24 != 4 : Should be 4
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 8 != 17 : Should be 17
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 25 != 23 : Should be 23
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 2 != 22 : Should be 22
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 13 != 9 : Should be 9
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 2 != 7 : Should be 7
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 10 != 18 : Should be 18
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 17 != 5 : Should be 5
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 20 != 16 : Should be 16
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 23 != 4 : Should be 4
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 1 != 3 : Should be 3
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 8 != 24 : Should be 24
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 14 != 3 : Should be 3
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 3 != 22 : Should be 22
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 17 != 6 : Should be 6
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 7 != 6 : Should be 6
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 3 != 14 : Should be 14
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 8 != 6 : Should be 6
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 25 != 12 : Should be 12
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 7 != 23 : Should be 23
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 24 != 1 : Should be 1
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 16 != 24 : Should be 24
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 5 != 25 : Should be 25
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 16 != 1 : Should be 1
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 2 != 25 : Should be 25
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 17 != 19 : Should be 19
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 9 != 22 : Should be 22
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 5 != 9 : Should be 9
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 2 != 5 : Should be 5
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 17 != 7 : Should be 7
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 2 != 4 : Should be 4
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 12 != 11 : Should be 11
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 15 != 17 : Should be 17
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 9 != 20 : Should be 20
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 23 != 5 : Should be 5
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 18 != 17 : Should be 17
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 4 != 22 : Should be 22
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 16 != 21 : Should be 21
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 12 != 9 : Should be 9
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 9 != 11 : Should be 11
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 12 != 24 : Should be 24
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 19 != 23 : Should be 23
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 22 != 16 : Should be 16
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 18 != 14 : Should be 14
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 16 != 6 : Should be 6
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 16 != 1 : Should be 1
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 19 != 2 : Should be 2
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 4 != 8 : Should be 8
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 16 != 15 : Should be 15
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 23 != 11 : Should be 11
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 8 != 25 : Should be 25
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 5 != 3 : Should be 3
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 14 != 21 : Should be 21
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 12 != 14 : Should be 14
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 14 != 23 : Should be 23
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 5 != 21 : Should be 21
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 13 != 11 : Should be 11
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 23 != 10 : Should be 10
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 15 != 21 : Should be 21
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 22 != 24 : Should be 24
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 24 != 22 : Should be 22
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 16 != 25 : Should be 25
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 4 != 13 : Should be 13
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 8 != 7 : Should be 7
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 8 != 6 : Should be 6
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 2 != 10 : Should be 10
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 20 != 11 : Should be 11
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 22 != 2 : Should be 2
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 4 != 17 : Should be 17
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 17 != 6 : Should be 6
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 22 != 15 : Should be 15
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 23 != 2 : Should be 2
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 13 != 21 : Should be 21
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 20 != 15 : Should be 15
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 15 != 21 : Should be 21
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 5 != 14 : Should be 14
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 20 != 8 : Should be 8
#
# ======================================================================
# FAIL: runTest (mod.testing.test_mode.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "d:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 154, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 17 != 11 : Should be 11
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.140s
#
# FAILED (failures=98)

# %%
test_mode(mode_poo)

# %%
def moda_funcional (arr):
    unique_items =unique_funcional(arr)

    count_occurrences = lambda item, arr:reduce(
        lambda count, x: count +1 if x == item else count,arr,0
    )
    frequency = reduce

# %%
test_mode(mode_funcional)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 test_mode(mode_funcional)
#
# NameError: name 'mode_funcional' is not defined

# %% [markdown]
# ## 9. Escribe una función que calcule la desviación estándar de una lista.
# `NOTE: no utilices librerías ni ninguna función ya construida. 😉`

# %%
#tu codigo aquí

# %%
# Para testear tu función
test_stdev(st_dev_imperativa)

# %%
test_stdev(st_dev_poo)

# %%
test_stdev(st_dev_funcional)

# %% [markdown]
# ## 10. Escribe una función para verificar si una cadena es un pangrama, es decir: si contiene todas las letras del alfabeto al menos una vez. Ten en cuenta que las cadenas pueden contener caracteres que no son letras.

# %%
#tu codigo aquí

# %%
# Para testear tu función
test_pangram(is_pangram_imperativa)

# %%
test_pangram(is_pangram_poo)

# %%
# Test para la función funcional
test_pangram(is_pangram_funcional)

# %% [markdown]
# ## 11. Escribe una función que reciba una cadena de palabras separadas por comas y devuelva una cadena de palabras separadas por comas ordenadas alfabéticamente.
#
# `NOTA: Puedes usar sorted pero no split y definitivamente no join! 🤪`

# %%
#tu codigo aquí

# %%
# Para testear tu función
test_alpha(sort_words_imperativa)

# %%
test_alpha(sort_words_poo)

# %%
test_alpha(sort_words_funcional)

# %% [markdown]
# ## 12. Escribe una función para verificar si una contraseña dada es fuerte (al menos 8 caracteres, al menos una minúscula, al menos una mayúscula, al menos un número y al menos un carácter especial). Debería devolver True si es fuerte y False si no lo es. Se permit el uso de regex

# %%
import re
def is_strong_password_imperativa(contraseña):
    patron_contraseña=r'(/(\d{1,}[a-z]{1,}[A-Z]{1,}/g)'

    (?=.*[a-z])(?=.*[A-Z]).{8,0}

# %%
# Para testear tu función
test_pass(is_strong_password_imperativa)

# %%
test_pass(is_strong_password_poo)

# %%
test_pass(is_strong_password_funcional)
