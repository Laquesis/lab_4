# %% [markdown]
# # Laboratorio: Programación en Python
#
# En este laboratorio, pondremos en práctica algunos de los conceptos que hemos aprendido recientemente. El objetivo es que implementes cada función utilizando tres enfoques diferentes en Python: **programación imperativa**, **programación orientada a objetos** y **programación funcional**.
#
# > **NOTA:** En este laboratorio deberías intentar escribir todas las funciones por ti mismo utilizando únicamente la sintaxis más básica de Python, sin utilizar funciones predefinidas como `len`, `count`, `sum`, `max`, `min`, `in`, etc. ¡Dale una oportunidad! 🧑🏻‍💻👩🏻‍💻
#
# La celda después de cada ejercicio contiene pruebas para verificar si tu función funciona como se espera.

# %%
from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Escribe una función que devuelva el mayor de dos números

# %%
#tu codigo aquí
def greater_imperativa(a, b):
    if a > b:
        return a
    else:
        return b

# %%
# Para testear tu función
test_greater(greater_imperativa)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.042s
#
# OK

# %%
class Comparador:
    @staticmethod
    def greater_poo(a, b):
        return a if a > b else b

greater_poo = Comparador.greater_poo

# %%
test_greater(greater_poo)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.033s
#
# OK

# %%
greater_funcional = (lambda a, b: a if a > b else b)

# %%
test_greater(greater_funcional)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.043s
#
# OK

# %% [markdown]
# ## 2. Ahora escribe una función que devuelva el elemento más grande de una lista numerica

# %%
#tu codigo aquí
def greatest_imperativa(arr):
    if not arr:  # Manejar el caso de una lista vacía
        return None

    max_num = arr[0]  # Asumimos que el primer elemento es el máximo
    index = 1

    while True:
        try:
            if arr[index] > max_num:  # Comparamos el elemento actual con max_num
                max_num = arr[index]  # Actualizamos max_num si encontramos un nuevo máximo
            index += 1  # Aumentamos el índice para continuar al siguiente elemento
        except IndexError:
            break  # Si index excede el rango, salimos del bucle

    return max_num

# %%
# Para testear tu función
test_greatest(greatest_imperativa)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.049s
#
# OK

# %%
class test_greatest:
  def __init__(self, arr):
    self.arr = arr

  def generar(arr):
    max_num = arr[0]  # Asumimos que el primer elemento es el máximo
    index = 1
    while True:
        try:
            if arr[index] > max_num:  # Comparamos el elemento actual con max_num
                max_num = arr[index]  # Actualizamos max_num si encontramos un nuevo máximo
            index += 1  # Aumentamos el índice para continuar al siguiente elemento
        except IndexError:
            break  # Si index excede el rango, salimos del bucle

    return max_num

# %%
test_greatest(test_greatest)

# %%
greater_funcional= lambda arr : 1 if max_num =)

# %%
test_greatest(greatest_funcional)

# %% [markdown]
# ## 3. Escribe una función que sume todos los elementos de una lista

# %%
#tu codigo aquí
def sum_imperativa (arr):
    sumatori=0
    index=0
    while True:
        try:
            sumatori += arr[index] 
            index += 1
        except IndexError:
            break 
    return sumatori

# %%
# Para testear tu función
test_sum(sum_imperativa)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.045s
#
# OK

# %%
class sum_poo:
    def __init__(self, arr):
        self.arr = arr
    def sum(self,arr):
        sumatori=0
        index=0
        while True:
            try:
                sumatori += arr[index] 
                index += 1
            except IndexError:
                break 
        return sumatori

# %%
test_sum(sum_poo)
# Out:
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51FE8890> != 1062 : Should be 1062
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51FE8890> != -5492 : Should be -5492
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E91910> != -1311 : Should be -1311
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51FE8890> != -5096 : Should be -5096
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E92450> != 4105 : Should be 4105
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51FE8890> != 5001 : Should be 5001
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B520A5880> != 613 : Should be 613
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51FE8890> != 495 : Should be 495
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B520A6E10> != 2324 : Should be 2324
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51FE8890> != 1910 : Should be 1910
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B520A63F0> != 8151 : Should be 8151
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B520A6B40> != -6177 : Should be -6177
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51FEB110> != 4288 : Should be 4288
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51FEA840> != 4799 : Should be 4799
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51FEA5D0> != -822 : Should be -822
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51FEA420> != 4006 : Should be 4006
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51FEA330> != -779 : Should be -779
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51FEA900> != 1207 : Should be 1207
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51FEA5D0> != -10387 : Should be -10387
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51FEA030> != 1903 : Should be 1903
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E93D70> != 8615 : Should be 8615
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E92780> != 2984 : Should be 2984
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51FEABD0> != 1008 : Should be 1008
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E93D70> != 5217 : Should be 5217
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E92450> != 6463 : Should be 6463
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E919D0> != -1085 : Should be -1085
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E93BF0> != -7574 : Should be -7574
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E913D0> != -3863 : Should be -3863
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E90CB0> != -1732 : Should be -1732
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E90E90> != 5425 : Should be 5425
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51FEABD0> != 7217 : Should be 7217
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1D520> != -10221 : Should be -10221
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1E600> != -5718 : Should be -5718
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1C350> != 7894 : Should be 7894
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1C680> != 5502 : Should be 5502
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1C740> != 7206 : Should be 7206
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1C320> != 1518 : Should be 1518
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1F680> != -2643 : Should be -2643
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1F770> != 4834 : Should be 4834
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1F0E0> != 1707 : Should be 1707
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1D940> != -1094 : Should be -1094
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1F3B0> != -5479 : Should be -5479
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1CA70> != 35 : Should be 35
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1F050> != -6914 : Should be -6914
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1FBF0> != -2369 : Should be -2369
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E913D0> != 4220 : Should be 4220
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E913D0> != 50 : Should be 50
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E91250> != -6791 : Should be -6791
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51FE8740> != 989 : Should be 989
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E913D0> != 104 : Should be 104
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51FEA690> != -1291 : Should be -1291
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E92840> != 6777 : Should be 6777
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E90740> != 1273 : Should be 1273
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E912E0> != -2380 : Should be -2380
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51FEA5D0> != -1242 : Should be -1242
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E92EA0> != 5696 : Should be 5696
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51FEA5A0> != 3375 : Should be 3375
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51FEB170> != -190 : Should be -190
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51FEAEA0> != -17 : Should be -17
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51FE9B80> != 1895 : Should be 1895
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51FEB170> != -619 : Should be -619
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1F050> != 11886 : Should be 11886
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E91B80> != 2688 : Should be 2688
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1DA30> != -671 : Should be -671
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1FBF0> != -2840 : Should be -2840
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1EC90> != -2958 : Should be -2958
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1ED50> != 1354 : Should be 1354
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1F770> != 4445 : Should be 4445
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1FEF0> != 5893 : Should be 5893
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1C140> != 4052 : Should be 4052
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1E930> != -3325 : Should be -3325
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1DE50> != 3371 : Should be 3371
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1D040> != 2675 : Should be 2675
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1D5E0> != -4981 : Should be -4981
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1C8F0> != -819 : Should be -819
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1C8F0> != -220 : Should be -220
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51DE2330> != -2449 : Should be -2449
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51DE0FE0> != 583 : Should be 583
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1DA60> != 9754 : Should be 9754
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1CDD0> != -998 : Should be -998
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1FB90> != 1580 : Should be 1580
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1C320> != -1386 : Should be -1386
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1FBF0> != 10103 : Should be 10103
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1FC20> != 11594 : Should be 11594
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1C320> != 6735 : Should be 6735
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1E600> != 2500 : Should be 2500
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51FEA3F0> != -221 : Should be -221
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51F1DD00> != -2767 : Should be -2767
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E91B80> != -1532 : Should be -1532
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E93170> != -650 : Should be -650
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E93170> != 2900 : Should be 2900
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E92240> != 438 : Should be 438
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E90740> != -6125 : Should be -6125
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E919D0> != -309 : Should be -309
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E91C40> != 2839 : Should be 2839
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E92450> != -2307 : Should be -2307
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E919D0> != -467 : Should be -467
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E91250> != 6432 : Should be 6432
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E921B0> != 4260 : Should be 4260
#
# ======================================================================
# FAIL: runTest (mod.testing.test_sum.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 53, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: <__main__.sum_poo object at 0x0000021B51E92BD0> != 818 : Should be 818
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.064s
#
# FAILED (failures=100)

# %%
sum_funcional = lambda arr: 0 if arr==[] else reduce (lambda a,b: a+b,arr)

# %%
test_sum(sum_funcional)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.050s
#
# OK

# %% [markdown]
# ## 4. Escribe otra función que multiplique todos los elementos de una lista

# %%
#tu codigo aquí
def mult_imperativa (arr):
    multiplicador=1
    index=0
    while True:
        try:
            multiplicador *= arr[index] 
            index += 1
        except IndexError:
            break 
    return multiplicador

# %%
# Para testear tu función
test_mult(mult_imperativa)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.045s
#
# OK

# %%
class mult_poo:

# %%
test_mult(mult_poo)

# %%
mult_funcional = lambda arr:reduce (lambda a,b: a*b,arr,1) if arr != [] else 0

# %%
test_mult(mult_funcional)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.047s
#
# OK

# %% [markdown]
# ## 5. Ahora combina esas dos ideas y escribe una función que reciba una lista y ya sea "+" o "*", y produzca el resultado acorde

# %%
#tu codigo aquí
def operaciones_imperativa(arr,signo):
    if signo == "+":
        return sum_imperativa(arr)
    elif signo == "*":
        return mult_imperativa(arr)

# %%
# Para testear tu función
test_operations(operaciones_imperativa)
# Out:
# FF.F.F.FFFFF...F..FFF...F....F.F.....F.F....F.FFFFF.....FF..FFFFF.F..FF.F....FFF.F..FF.F.F.FF..FFFF.
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 66 : Should be 66
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 10 : Should be 10
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 51 : Should be 51
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: -604661760000000 != -4 : Should be -4
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 53 : Should be 53
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != -25 : Should be -25
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 22649241600 != 29 : Should be 29
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 72 : Should be 72
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 839965883904000000 != -5 : Should be -5
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != -7 : Should be -7
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != -32 : Should be -32
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != -15 : Should be -15
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 37 : Should be 37
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != -101 : Should be -101
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 34 : Should be 34
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 9 : Should be 9
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 25 : Should be 25
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 17 : Should be 17
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != -48 : Should be -48
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != -69 : Should be -69
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 21742388846056282521600000 != -6 : Should be -6
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 15 : Should be 15
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 23 : Should be 23
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != -9 : Should be -9
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 16 : Should be 16
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != -7 : Should be -7
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != -5 : Should be -5
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != -68 : Should be -68
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 10 : Should be 10
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: -3715891200000000 != 29 : Should be 29
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 42 : Should be 42
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != -51 : Should be -51
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != -7 : Should be -7
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 29 : Should be 29
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 68 : Should be 68
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != -13 : Should be -13
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != -4 : Should be -4
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: -1012118780425435906855403520000000000000000 != -4 : Should be -4
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != -50 : Should be -50
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != -19 : Should be -19
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 10536960000000 != 27 : Should be 27
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != -91 : Should be -91
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: -5832000 != -12 : Should be -12
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 35 : Should be 35
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != -40 : Should be -40
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 31 : Should be 31
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != -22 : Should be -22
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != -95 : Should be -95
#
# ======================================================================
# FAIL: runTest (mod.testing.test_operations.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 91, in runTest
#     self.assertEqual(fn(*self.input), self.output, f"Should be {self.output}")
# AssertionError: -6221969510400000000 != 35 : Should be 35
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.056s
#
# FAILED (failures=49)

# %%
test_operations(operaciones_poo)

# %%
operaciones_funcional = lambda arr,signo: lambda( if signo =="+" ,sum_poo(arr))

# %%
test_operations(operaciones_funcional)

# %% [markdown]
# ## 6. Escribe una función que devuelva el factorial de un número.

# %%
# Fórmula factorial
# n! = n * (n - 1) *...*1

# Este código define una función llamada "factorial" que toma una entrada "n". La función utiliza un bucle for para iterar a través del rango de números
# desde 1 hasta n+1. Para cada número en ese rango, multiplica el valor actual de x por el número en el rango. Al final del bucle,
# la función devuelve el valor final de x, que será el factorial del número de entrada "n".

# El factorial de un entero positivo n es el producto de todos los enteros positivos menores o iguales a n.
# Por ejemplo, el factorial de 6 (escrito "6!") es 6 * 5 * 4 * 3 * 2 * 1 = 720.

# Así que esta función toma una entrada de cualquier entero positivo y devuelve el factorial de ese número.

# %%
#tu codigo aquí
def factorial_imperativa(n):
    factorial=0
    if n <= 0:
        return None

    while n>0:
        try:
            factorial*=n
            n=n-1
        except Exception:
            break 
    return factorial

# %%
# Para testear tu función
test_factorial(factorial_imperativa)
# Out:
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 8841761993739701954543616000000 : Should be 8841761993739701954543616000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 1551118753287382280224243016469303211063259720016986112000000000000 : Should be 1551118753287382280224243016469303211063259720016986112000000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 8222838654177922817725562880000000 : Should be 8222838654177922817725562880000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 1405006117752879898543142606244511569936384000000000 : Should be 1405006117752879898543142606244511569936384000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 8841761993739701954543616000000 : Should be 8841761993739701954543616000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 36471110918188685288249859096605464427167[49 chars]00000 : Should be 36471110918188685288249859096605464427167635314049524593701628500267962436943872000000000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 13868311854568983573793901972038940634590[35 chars]00000 : Should be 138683118545689835737939019720389406345902876772687432540821294940160000000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 93326215443944152681699238856266700490715[112 chars]00000 : Should be 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 2432902008176640000 : Should be 2432902008176640000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 1 : Should be 1
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 2350561331282878571829474910515074683828862318181142924420699914240000000000000 : Should be 2350561331282878571829474910515074683828862318181142924420699914240000000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 11978571669969891796072783721689098736458[55 chars]00000 : Should be 11978571669969891796072783721689098736458938142546425857555362864628009582789845319680000000000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 3628800 : Should be 3628800
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 61234458376886086861524070385274672740778[58 chars]00000 : Should be 61234458376886086861524070385274672740778091784697328983823014963978384987221689274204160000000000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 51090942171709440000 : Should be 51090942171709440000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 44701154615126843408912571381250511100768[60 chars]00000 : Should be 4470115461512684340891257138125051110076800700282905015819080092370422104067183317016903680000000000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 710998587804863451854045647463724949736497978881168458687447040000000000000 : Should be 710998587804863451854045647463724949736497978881168458687447040000000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 18548264225739843911479684564554628438022[89 chars]00000 : Should be 185482642257398439114796845645546284380220968949399346684421580986889562184028199319100141244804501828416633516851200000000000000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 14518309202828586963407078408630828498374[68 chars]00000 : Should be 145183092028285869634070784086308284983740379224208358846781574688061991349156420080065207861248000000000000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 815915283247897734345611269596115894272000000000 : Should be 815915283247897734345611269596115894272000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 10333147966386144929666651337523200000000 : Should be 10333147966386144929666651337523200000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 710998587804863451854045647463724949736497978881168458687447040000000000000 : Should be 710998587804863451854045647463724949736497978881168458687447040000000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 479001600 : Should be 479001600
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 50758021387722479880085681217662522722600[38 chars]00000 : Should be 507580213877224798800856812176625227226004528988036003099405939480985600000000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 !=
000000000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 119622220865480194561963161495657715064383733760000000000 : Should be 119622220865480194561963161495657715064383733760000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 11324281178206297831457521158732046228731[70 chars]00000 : Should be 11324281178206297831457521158732046228731749579488251990048962825668835325234200766245086213177344000000000000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 99167793487094968920957140154189380115818[104 chars]00000 : Should be 991677934870949689209571401541893801158183648651267795444376054838492222809091499987689476037000748982075094738965754305639874560000000000000000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 371993326789901217467999448150835200000000 : Should be 371993326789901217467999448150835200000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 1124000727777607680000 : Should be 1124000727777607680000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 304888344611713860501504000000 : Should be 304888344611713860501504000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 12688693218588416410343338933516148080286[44 chars]00000 : Should be 126886932185884164103433389335161480802865516174545192198801894375214704230400000000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 13520015276784029625516656875949514214758[95 chars]00000 : Should be 135200152767840296255166568759495142147586866476906677791741734597153670771559994765685283954750449427751168336768008192000000000000000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 12438414054641307255475324325873553077577[97 chars]00000 : Should be 12438414054641307255475324325873553077577991715875414356840239582938137710983519518443046123837041347353107486982656753664000000000000000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 230843697339241380472092742683027581083278564571807941132288000000000000 : Should be 230843697339241380472092742683027581083278564571807941132288000000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 815915283247897734345611269596115894272000000000 : Should be 815915283247897734345611269596115894272000000000
#
# ======================================================================
# FAIL: runTest (mod.testing.test_factorial.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py", line 118, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 0 != 18548264225739843911479684564554628438022[89 chars]00000 : Should be 185482642257398439114796845645546284380220968949399346684421580986889562184028199319100141244804501828416633516851200000000000000000000
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.066s
#
# FAILED (failures=100)

# %%
test_factorial(factorial_poo)

# %%
test_factorial(factorial_funcional)

# %% [markdown]
# ## 7. Escribe una función que tome una lista y devuelva una lista de los valores únicos.
#
# `NOTE: No podemos usar set. 🤔`

# %%
#tu codigo aquí
def unique_imperativa (arr):
    unique_list=[]
    index=0

    while True:
        try:
            item =arr[index]
            is_unique = True
            index +=1
        except IndexError:
            break

# %%
# Para testear tu función
test_unique(unique_imperativa)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[62], line 2
#       1 # Para testear tu función
# ----> 2 test_unique(unique_imperativa)
#
# File e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py:143, in test_unique(fn)
#     141         arr.append(random.randint(-100, 100))
#     142     suite.addTest(TestKnown(arr, set(arr)))
# --> 143 unittest.TextTestRunner().run(suite)
#
# File c:\Python312\Lib\unittest\runner.py:240, in TextTestRunner.run(self, test)
#     238     startTestRun()
#     239 try:
# --> 240     test(result)
#     241 finally:
#     242     stopTestRun = getattr(result, 'stopTestRun', None)
#
# File c:\Python312\Lib\unittest\suite.py:84, in BaseTestSuite.__call__(self, *args, **kwds)
#      83 def __call__(self, *args, **kwds):
# ---> 84     return self.run(*args, **kwds)
#
# File c:\Python312\Lib\unittest\suite.py:122, in TestSuite.run(self, result, debug)
#     119         continue
#     121 if not debug:
# --> 122     test(result)
#     123 else:
#     124     test.debug()
#
# File c:\Python312\Lib\unittest\case.py:690, in TestCase.__call__(self, *args, **kwds)
#     689 def __call__(self, *args, **kwds):
# --> 690     return self.run(*args, **kwds)
#
# File c:\Python312\Lib\unittest\case.py:634, in TestCase.run(self, result)
#     632 outcome.expecting_failure = expecting_failure
#     633 with outcome.testPartExecutor(self):
# --> 634     self._callTestMethod(testMethod)
#     635 outcome.expecting_failure = False
#     636 with outcome.testPartExecutor(self):
#
# File c:\Python312\Lib\unittest\case.py:589, in TestCase._callTestMethod(self, method)
#     588 def _callTestMethod(self, method):
# --> 589     if method() is not None:
#     590         warnings.warn(f'It is deprecated to return a value that is not None from a '
#     591                       f'test case ({method})', DeprecationWarning, stacklevel=3)
#
# File e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py:135, in test_unique.<locals>.TestKnown.runTest(self)
#     134 def runTest(self):
# --> 135     self.assertEqual(set(fn(self.input)), self.output, f"Should be {self.output}")
#
# Cell In[61], line 6, in unique_imperativa(arr)
#       3 unique_list=[]
#       4 index=0
# ----> 6 while True:
#       7     try:
#       8         item =arr[index]
#
# KeyboardInterrupt:

# %%
class Unique:
    def unique_poo(arr):
        unique_list =[]
        index =0

        while True:
            try:
                item =arr[index]
                if Unique.is_unique(item,unique_list):
                    unique_list.append(item)
                index +=1
                
            except IndexError:
                break
    def is_unique(item, unique_list):
        unique_index=0

        while True:
            try:
                if unique_list[unique_index] == item:
                    return False
                unique_index +=1
            except IndexError:
                break
        return True

# %%
test_unique(unique_poo)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 test_unique(unique_poo)
#
# NameError: name 'unique_poo' is not defined

# %%
unique_funcional = lambda arr: reduce (
    lambda acc,item: acc + [item] if reduce( 
        lambda x,y :  x or (y ==item),acc,False)
        ==False else acc,arr,[]
)

# %%
test_unique(unique_funcional)
# Out:
# ....
# ................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.521s
#
# OK

# %% [markdown]
# ## 8. Escribe una función que devuelva la moda de una lista, es decir: el elemento que aparece más veces.
#
# `NOTE: No se debe usar count... 🧐`

# %%
#tu codigo aquí
def moda_imperativa (arr):
    unique_list = unique_imperativa(arr)
    max_frecuencia =-1
    moda = None

    unique_index=0
    while True:
        try:
            num= unique_list[unique_index]
            frecuencia =0
            index =0

            while True:
                try:
                    if arr[index]==num:
                        frecuencia +=1
                    index +=1
                except IndexError:
                    break
            if frecuencia > max_frecuencia:
                max_frecuencia = frecuencia
                moda = num
                
            unique_index +=1

        except IndexError:
            break

        return moda

# %%
# Para testear tu función
test_mode(moda_imperativa)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[68], line 2
#       1 # Para testear tu función
# ----> 2 test_mode(moda_imperativa)
#
# File e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py:163, in test_mode(fn)
#     161     arr += [random.randint(1, 25)] * 50
#     162     suite.addTest(TestKnown(arr, mode(arr)))
# --> 163 unittest.TextTestRunner().run(suite)
#
# File c:\Python312\Lib\unittest\runner.py:240, in TextTestRunner.run(self, test)
#     238     startTestRun()
#     239 try:
# --> 240     test(result)
#     241 finally:
#     242     stopTestRun = getattr(result, 'stopTestRun', None)
#
# File c:\Python312\Lib\unittest\suite.py:84, in BaseTestSuite.__call__(self, *args, **kwds)
#      83 def __call__(self, *args, **kwds):
# ---> 84     return self.run(*args, **kwds)
#
# File c:\Python312\Lib\unittest\suite.py:122, in TestSuite.run(self, result, debug)
#     119         continue
#     121 if not debug:
# --> 122     test(result)
#     123 else:
#     124     test.debug()
#
# File c:\Python312\Lib\unittest\case.py:690, in TestCase.__call__(self, *args, **kwds)
#     689 def __call__(self, *args, **kwds):
# --> 690     return self.run(*args, **kwds)
#
# File c:\Python312\Lib\unittest\case.py:634, in TestCase.run(self, result)
#     632 outcome.expecting_failure = expecting_failure
#     633 with outcome.testPartExecutor(self):
# --> 634     self._callTestMethod(testMethod)
#     635 outcome.expecting_failure = False
#     636 with outcome.testPartExecutor(self):
#
# File c:\Python312\Lib\unittest\case.py:589, in TestCase._callTestMethod(self, method)
#     588 def _callTestMethod(self, method):
# --> 589     if method() is not None:
#     590         warnings.warn(f'It is deprecated to return a value that is not None from a '
#     591                       f'test case ({method})', DeprecationWarning, stacklevel=3)
#
# File e:\IA\EJERCICIOS IA\lab_4\lab_4\mod\testing.py:154, in test_mode.<locals>.TestKnown.runTest(self)
#     153 def runTest(self):
# --> 154     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#
# Cell In[65], line 3, in moda_imperativa(arr)
#       2 def moda_imperativa (arr):
# ----> 3     unique_list = unique_imperativa(arr)
#       4     max_frecuencia =-1
#       5     moda = None
#
# Cell In[61], line 6, in unique_imperativa(arr)
#       3 unique_list=[]
#       4 index=0
# ----> 6 while True:
#       7     try:
#       8         item =arr[index]
#
# KeyboardInterrupt:

# %%
test_mode(mode_poo)

# %%
def moda_funcional (arr):
    unique_items =unique_funcional(arr)

    count_occurrences = lambda item, arr:reduce(
        lambda count, x: count +1 if x == item else count,arr,0
    )
    frequency = reduce

# %%
test_mode(mode_funcional)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 test_mode(mode_funcional)
#
# NameError: name 'mode_funcional' is not defined

# %% [markdown]
# ## 9. Escribe una función que calcule la desviación estándar de una lista.
# `NOTE: no utilices librerías ni ninguna función ya construida. 😉`

# %%
#tu codigo aquí

# %%
# Para testear tu función
test_stdev(st_dev_imperativa)

# %%
test_stdev(st_dev_poo)

# %%
test_stdev(st_dev_funcional)

# %% [markdown]
# ## 10. Escribe una función para verificar si una cadena es un pangrama, es decir: si contiene todas las letras del alfabeto al menos una vez. Ten en cuenta que las cadenas pueden contener caracteres que no son letras.

# %%
#tu codigo aquí

# %%
# Para testear tu función
test_pangram(is_pangram_imperativa)

# %%
test_pangram(is_pangram_poo)

# %%
# Test para la función funcional
test_pangram(is_pangram_funcional)

# %% [markdown]
# ## 11. Escribe una función que reciba una cadena de palabras separadas por comas y devuelva una cadena de palabras separadas por comas ordenadas alfabéticamente.
#
# `NOTA: Puedes usar sorted pero no split y definitivamente no join! 🤪`

# %%
#tu codigo aquí

# %%
# Para testear tu función
test_alpha(sort_words_imperativa)

# %%
test_alpha(sort_words_poo)

# %%
test_alpha(sort_words_funcional)

# %% [markdown]
# ## 12. Escribe una función para verificar si una contraseña dada es fuerte (al menos 8 caracteres, al menos una minúscula, al menos una mayúscula, al menos un número y al menos un carácter especial). Debería devolver True si es fuerte y False si no lo es. Se permit el uso de regex

# %%
import re
def is_strong_password_imperativa(contraseña):
    patron_contraseña=r'(/(\d{1,}[a-z]{1,}[A-Z]{1,}/g)'

    (?=.*[a-z])(?=.*[A-Z]).{8,0}

# %%
# Para testear tu función
test_pass(is_strong_password_imperativa)

# %%
test_pass(is_strong_password_poo)

# %%
test_pass(is_strong_password_funcional)
